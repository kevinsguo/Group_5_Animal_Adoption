# %%
import pandas as pd
import numpy as np
from config import db_password

# %%
# create database connection
import psycopg2
connection = psycopg2.connect(
    host = 'projectanimal.c2jqqtcm0i1p.us-east-2.rds.amazonaws.com',
    port = 5432,
    user = 'postgres',
    password = db_password,
    database='projectanimal'
    )
cursor=connection.cursor()

# %%
# import intake data
sql = '''
select * from animal_intake'''

intake_df = pd.read_sql(sql,con=connection)
intake_df.head()
# Out:
#   animal_id     datetime_intake                 found_location  \
# 0   A730601 2016-07-07 12:11:00   1109 Shady Ln in Austin (TX)
# 1   A683644 2014-07-13 11:02:00
# 2   A676515 2014-04-11 08:45:00  615 E. Wonsley in Austin (TX)
# 3   A742953 2017-01-31 13:30:00
# 4   A679549 2014-05-22 15:43:00  124 W Anderson in Austin (TX)
#
#        intake_type intake_condition animal_type_intake name_intake  \
# 0            Stray           Normal                Cat          No
# 1  Owner Surrender        Maternity                Dog         Yes
# 2            Stray           Normal                Dog         Yes
# 3            Stray           Normal                Dog          No
# 4            Stray           Normal                Cat         Yes
#
#       sex_intake color_intake    breed_type
# 0    Intact Male        Tabby           Mix
# 1  Intact Female      Bicolor           Mix
# 2    Intact Male      Bicolor           Mix
# 3    Intact Male      Bicolor  Hound Breeds
# 4    Intact Male      Bicolor           Mix

# %%
# import outcome data
sql = '''
select * from animal_outcome'''

outcome_df = pd.read_sql(sql,con=connection)
outcome_df.head()
# Out:
#   animal_id    datetime_outcome     outcome_type sex_upon_outcome  \
# 0   A730601 2016-07-08 09:00:00         Transfer    Neutered Male
# 1   A683644 2014-11-06 10:06:00         Adoption    Spayed Female
# 2   A676515 2014-04-14 18:38:00  Return to Owner    Neutered Male
# 3   A742953 2017-02-04 14:17:00         Transfer      Intact Male
# 4   A679549 2014-06-16 13:54:00         Transfer    Neutered Male
#
#   fixed_changed   age_bucket     datetime_length
# 0             1  7-12 months  0.8673611111111111
# 1             1    1-6 weeks  115.96111111111111
# 2             1   1-6 months  3.4118055555555555
# 3             0    1-3 years   4.032638888888889
# 4             1   1-6 months  24.924305555555556

# %%
# merge data
df = intake_df.merge(outcome_df, on='animal_id', how='left')
df.head()
# Out:
#   animal_id     datetime_intake                 found_location  \
# 0   A730601 2016-07-07 12:11:00   1109 Shady Ln in Austin (TX)
# 1   A683644 2014-07-13 11:02:00
# 2   A676515 2014-04-11 08:45:00  615 E. Wonsley in Austin (TX)
# 3   A742953 2017-01-31 13:30:00
# 4   A679549 2014-05-22 15:43:00  124 W Anderson in Austin (TX)
#
#        intake_type intake_condition animal_type_intake name_intake  \
# 0            Stray           Normal                Cat          No
# 1  Owner Surrender        Maternity                Dog         Yes
# 2            Stray           Normal                Dog         Yes
# 3            Stray           Normal                Dog          No
# 4            Stray           Normal                Cat         Yes
#
#       sex_intake color_intake    breed_type    datetime_outcome  \
# 0    Intact Male        Tabby           Mix 2016-07-08 09:00:00
# 1  Intact Female      Bicolor           Mix 2014-11-06 10:06:00
# 2    Intact Male      Bicolor           Mix 2014-04-14 18:38:00
# 3    Intact Male      Bicolor  Hound Breeds 2017-02-04 14:17:00
# 4    Intact Male      Bicolor           Mix 2014-06-16 13:54:00
#
#       outcome_type sex_upon_outcome fixed_changed   age_bucket  \
# 0         Transfer    Neutered Male             1  7-12 months
# 1         Adoption    Spayed Female             1    1-6 weeks
# 2  Return to Owner    Neutered Male             1   1-6 months
# 3         Transfer      Intact Male             0    1-3 years
# 4         Transfer    Neutered Male             1   1-6 months
#
#       datetime_length
# 0  0.8673611111111111
# 1  115.96111111111111
# 2  3.4118055555555555
# 3   4.032638888888889
# 4  24.924305555555556
